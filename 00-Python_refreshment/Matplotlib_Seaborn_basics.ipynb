# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# %%
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Simple Line Plot")
plt.show()

# %%
# Scatter
plt.scatter(x, y)
plt.title("Scatter Plot")
plt.show()

# %%
# BAr

names=['A', 'B', 'C']
scores=[80,90,34]

plt.bar(names, scores)
plt.title("bar plot")
plt.show()

# %%
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.title("Histogram")
plt.show()

# %%
import seaborn as sns

tips = sns.load_dataset("tips")
sns.histplot(tips["total_bill"])
plt.show()

sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %% [markdown]
# ### 1.Their are many visualization libraries, choose the one which you comfortable with, Libraries like plotly make the visualization interactive

# %% [markdown]
# ### 2. Matplotlib Basics
#
# `plt.plot() — line plot`
#
# `plt.scatter() — scatter plot`
#
# `plt.bar() — bar chart`
#
# `plt.hist() — histogram`
#
# `plt.boxplot() — box plot`
#
# ### 3. Labels & Titles
#
# `plt.xlabel()`
#
# `plt.ylabel()`
#
# `plt.title()`
#
# ### 4. Figure Control
#
# `plt.figure(figsize=(w,h))`
#
# `plt.show()`
#
# ### 5. Subplots
#
# `plt.subplot(r, c, i)`
#
# `plt.subplots()`
#
# Used for:
#
# -Comparing multiple plots
#
# ### 6. Grid & Style (Matplotlib)
#
# `plt.grid(True)`

# %% [markdown]
# ### 10. Seaborn Basics
#
# **Built on Matplotlib**
#
# -Cleaner default visuals
#
# -Easier statistical plots
#
# ### 11. Common Seaborn Plots
#
# `sns.histplot()` — distribution
#
# `sns.boxplot()` — box plot
#
# `sns.countplot()` — category counts
#
# `sns.scatterplot()` — scatter
#
# `sns.lineplot() `— line
#
# ### 12. Relationship Plots
#
# `sns.pairplot()` — all feature relations
#
# `sns.heatmap()` — matrix view
#
# Used for:
#
# -Correlation analysis
#
# -Feature relationships
#
# ### 13. Correlation Heatmap (VERY IMPORTANT)
# `corr = df.corr()`
# `sns.heatmap(corr, annot=True)`
#
# Used for:
#
# -Feature selection
#
# -Multicollinearity detection
#
# ### 14. Categorical Analysis
#
# `sns.countplot(x="cat", data=df)`
#
# `sns.boxplot(x="cat", y="target", data=df)`
#
# Used for:
#
# -Category impact on target
#
# ### 15. Facet & Multi-Plots
#
# `sns.FacetGrid()`
#
# `sns.catplot()`
#
# Used for:
#
# -Split analysis by category
#
# ### 16. Saving Plots
#
# `plt.savefig("plot.png")`
#
# ### 17. ML Debugging with Plots
#
# Actual vs Predicted scatter
#
# Residual plots
#
# Loss vs epochs line plot
